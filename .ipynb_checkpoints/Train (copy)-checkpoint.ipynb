# %%
import os
from scipy.io import wavfile
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from keras.layers import Conv2D, MaxPool2D, Flatten, LSTM
from keras.layers import Dropout, Dense, TimeDistributed
from keras.models import Sequential, load_model
from keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
from tqdm import tqdm
import itertools
from python_speech_features import mfcc, logfbank
import pickle
from keras.callbacks import ModelCheckpoint
from cfg import Config
from sklearn.metrics import confusion_matrix
import librosa
# Out:
# Using TensorFlow backend.
# /home/thanh_dat/anaconda3/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/thanh_dat/anaconda3/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/thanh_dat/anaconda3/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/thanh_dat/anaconda3/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/thanh_dat/anaconda3/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/thanh_dat/anaconda3/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/thanh_dat/anaconda3/envs/py3.6/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/thanh_dat/anaconda3/envs/py3.6/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/thanh_dat/anaconda3/envs/py3.6/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/thanh_dat/anaconda3/envs/py3.6/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/thanh_dat/anaconda3/envs/py3.6/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/thanh_dat/anaconda3/envs/py3.6/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def check_data():
    if os.path.isfile(config.p_path):
        print('Loadning existing data for {} model'.format(config.mode))
        with open(config.p_path, 'rb') as handle:
            tmp = pickle.load(handle)
            return tmp
    else:
        return None

def build_rand_feat():
    tmp = check_data()
    if tmp:
        return tmp.data[0], tmp.data[1]
    X = []
    y = []
    _min, _max = float('inf'), -float('inf')
    print('tqdm: ',n_samples)
    for _ in tqdm(range(int(n_samples))):
        rand_class = np.random.choice(class_dist.index, p = prob_dist)
        file = np.random.choice(df[df.label==rand_class].index)
        rate, wav = wavfile.read('clean_voice/'+file)
        label = df.at[file, 'label']
        rand_index = np.random.randint(0, wav.shape[0]-config.step)
        sample = wav[rand_index:rand_index+config.step]
        X_sample = mfcc(sample, rate, numcep=config.nfeat, nfilt=config.nfilt, nfft=config.nfft)
        _min = min(np.amin(X_sample), _min)
        _max = max(np.amax(X_sample), _max)
        X.append(X_sample)
        y.append(classes.index(label))
    config.min = _min
    config.max = _max
    X, y = np.array(X), np.array(y)
    X = (X - _min) / (_max - _min)
    if config.mode == 'conv':
        X = X.reshape(X.shape[0], X.shape[1], X.shape[2], 1)
    elif config.mode == 'time':
        X = X.reshape(X.shape[0], X.shape[1], X.shape[2])
    y = to_categorical(y, num_classes=8)
    config.data = (X, y)

    with open(config.p_path, 'wb') as handle:
        pickle.dump(config, handle, protocol=2)

    return X, y

# %%
def get_conv_model():
    model = Sequential()
    model.add(Conv2D(16, (3, 3), activation='relu', strides = (1, 1),padding='same', input_shape=input_shape))
    model.add(Conv2D(32, (3, 3), activation='relu', strides = (1, 1),padding='same', input_shape=input_shape))
    model.add(Conv2D(64, (3, 3), activation='relu', strides = (1, 1),padding='same', input_shape=input_shape))
    model.add(Conv2D(128, (3, 3), activation='relu', strides = (1, 1),padding='same', input_shape=input_shape))
    model.add(MaxPool2D((2,2)))
    model.add(Dropout(0.5))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(8, activation='softmax'))
    model.summary()
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])
    return model


def get_recurrent_model():
    #shape of data for RNN is (n, time, feat)
    model = Sequential()
    model.add(LSTM(128, return_sequences=True, input_shape = input_shape))
    model.add(LSTM(128, return_sequences=True))
    model.add(LSTM(64, return_sequences=True))
    model.add(LSTM(32, return_sequences=True))
    model.add(LSTM(16, return_sequences=True))
    model.add(Dropout(0.5))
    model.add(TimeDistributed(Dense(128, activation='relu')))
    model.add(TimeDistributed(Dense(64, activation='relu')))
    model.add(TimeDistributed(Dense(32, activation='relu')))
    model.add(TimeDistributed(Dense(16, activation='relu')))
    model.add(TimeDistributed(Dense(8, activation='relu')))
    model.add(Flatten())
    model.add(Dense(8, activation='softmax'))
    model.summary()
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])
    return model

# %%
df = pd.read_csv('voice_label.csv')
df.set_index('fname', inplace=True)

for f in df.index:
    rate, signal = wavfile.read('clean_voice/'+f)
    df.at[f, 'length'] = signal.shape[0]/rate

classes = list(np.unique(df.label))
class_dist = df.groupby(['label'])['length'].mean()

n_samples = 2*int(df['length'].sum())/0.1
prob_dist = class_dist/class_dist.sum()
choices = np.random.choice(class_dist.index, p = prob_dist)

# %%
fig, ax = plt.subplots()
ax.set_title('Class Distribution', y=1.08)
ax.pie(class_dist, labels=class_dist.index, autopct='%1.1f%%',
       shadow=False, startangle=90)
ax.axis('equal')
plt.show()

# %%
config = Config(mode='conv')

if config.mode == 'conv':
    X, y = build_rand_feat()
    print('y.shape', y.shape)
    y_flat = np.argmax(y, axis=1)
    input_shape = (X.shape[1], X.shape[2], 1)
    model = get_conv_model()

elif config.mode == 'time':
    X, y = build_rand_feat()
    print('y.shape', y.shape)
    y_flat = np.argmax(y, axis=1)
    input_shape = (X.shape[1], X.shape[2])
    model = get_recurrent_model()

class_weight = compute_class_weight('balanced',np.unique(y_flat),y_flat)
# Out:
# Loadning existing data for conv model
# y.shape (6760, 8)
# WARNING:tensorflow:From /home/thanh_dat/anaconda3/envs/py3.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 9, 13, 16)         160
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 13, 32)         4640
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 9, 13, 64)         18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 13, 128)        73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 6, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 6, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               393344
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 8)                 264
# =================================================================
# Total params: 501,096
# Trainable params: 501,096
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(X.shape)
print(input_shape)
print(y.shape)
print(y_flat.shape)
# Out:
# (6760, 9, 13, 1)
# (9, 13, 1)
# (6760, 8)
# (6760,)

# %%
checkpoint = ModelCheckpoint(config.model_path, monitor='val_acc', verbose=1, mode = 'max', save_best_only=True, save_weights_only=False, period=1)
print('class_weight: ',class_weight)
history = model.fit(X, y, epochs=40, batch_size=32, shuffle=True, validation_split=0.1, callbacks = [checkpoint])
model.save('voice_conv_test.h5')
# Out:
# class_weight:  [1.20714286 0.98141696 0.83087512 1.09032258 1.02798054 0.813282
#  1.06423174 1.12367021]
# WARNING:tensorflow:From /home/thanh_dat/anaconda3/envs/py3.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 6084 samples, validate on 676 samples
# Epoch 1/5
# 6084/6084 [==============================] - 3s 515us/step - loss: 1.3322 - acc: 0.4755 - val_loss: 0.9047 - val_acc: 0.6657
#
# Epoch 00001: val_acc improved from -inf to 0.66568, saving model to models/conv.model
# Epoch 2/5
# 6084/6084 [==============================] - 3s 466us/step - loss: 0.8052 - acc: 0.6833 - val_loss: 0.7395 - val_acc: 0.7234
#
# Epoch 00002: val_acc improved from 0.66568 to 0.72337, saving model to models/conv.model
# Epoch 3/5
# 6084/6084 [==============================] - 3s 467us/step - loss: 0.6781 - acc: 0.7301 - val_loss: 0.7096 - val_acc: 0.7204
#
# Epoch 00003: val_acc did not improve from 0.72337
# Epoch 4/5
# 6084/6084 [==============================] - 3s 459us/step - loss: 0.6081 - acc: 0.7533 - val_loss: 0.6899 - val_acc: 0.7485
#
# Epoch 00004: val_acc improved from 0.72337 to 0.74852, saving model to models/conv.model
# Epoch 5/5
# 6084/6084 [==============================] - 3s 464us/step - loss: 0.5702 - acc: 0.7811 - val_loss: 0.5734 - val_acc: 0.7766
#
# Epoch 00005: val_acc improved from 0.74852 to 0.77663, saving model to models/conv.model

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
#mang nay them 1 lop dense 32 truoc lop softmax cua conv
checkpoint = ModelCheckpoint(config.model_path, monitor='val_acc', verbose=1, mode = 'max', save_best_only=True, save_weights_only=False, period=1)
print('class_weight: ',class_weight)
history1 = model.fit(X, y, epochs=40, batch_size=16, shuffle=True, validation_split=0.1, callbacks = [checkpoint])
model.save('voice_conv_2.h5')
# Out:
# class_weight:  [1.20714286 0.98141696 0.83087512 1.09032258 1.02798054 0.813282
#  1.06423174 1.12367021]
# Train on 6084 samples, validate on 676 samples
# Epoch 1/40
# 6084/6084 [==============================] - 4s 611us/step - loss: 1.2388 - acc: 0.5222 - val_loss: 0.9025 - val_acc: 0.6612
#
# Epoch 00001: val_acc improved from -inf to 0.66124, saving model to models/conv.model
# Epoch 2/40
# 6084/6084 [==============================] - 3s 512us/step - loss: 0.7983 - acc: 0.6951 - val_loss: 0.8096 - val_acc: 0.6879
#
# Epoch 00002: val_acc improved from 0.66124 to 0.68787, saving model to models/conv.model
# Epoch 3/40
# 6084/6084 [==============================] - 3s 506us/step - loss: 0.7047 - acc: 0.7209 - val_loss: 0.6386 - val_acc: 0.7589
#
# Epoch 00003: val_acc improved from 0.68787 to 0.75888, saving model to models/conv.model
# Epoch 4/40
# 6084/6084 [==============================] - 3s 518us/step - loss: 0.6208 - acc: 0.7558 - val_loss: 0.6276 - val_acc: 0.7751
#
# Epoch 00004: val_acc improved from 0.75888 to 0.77515, saving model to models/conv.model
# Epoch 5/40
# 6084/6084 [==============================] - 3s 508us/step - loss: 0.5826 - acc: 0.7709 - val_loss: 0.5901 - val_acc: 0.7885
#
# Epoch 00005: val_acc improved from 0.77515 to 0.78846, saving model to models/conv.model
# Epoch 6/40
# 6084/6084 [==============================] - 3s 509us/step - loss: 0.5532 - acc: 0.7853 - val_loss: 0.6292 - val_acc: 0.7751
#
# Epoch 00006: val_acc did not improve from 0.78846
# Epoch 7/40
# 6084/6084 [==============================] - 3s 524us/step - loss: 0.5159 - acc: 0.7952 - val_loss: 0.5703 - val_acc: 0.7781
#
# Epoch 00007: val_acc did not improve from 0.78846
# Epoch 8/40
# 6084/6084 [==============================] - 3s 551us/step - loss: 0.5003 - acc: 0.8088 - val_loss: 0.5262 - val_acc: 0.7988
#
# Epoch 00008: val_acc improved from 0.78846 to 0.79882, saving model to models/conv.model
# Epoch 9/40
# 6084/6084 [==============================] - 3s 554us/step - loss: 0.4596 - acc: 0.8213 - val_loss: 0.4925 - val_acc: 0.8062
#
# Epoch 00009: val_acc improved from 0.79882 to 0.80621, saving model to models/conv.model
# Epoch 10/40
# 6084/6084 [==============================] - 4s 579us/step - loss: 0.4480 - acc: 0.8243 - val_loss: 0.4737 - val_acc: 0.8284
#
# Epoch 00010: val_acc improved from 0.80621 to 0.82840, saving model to models/conv.model
# Epoch 11/40
# 6084/6084 [==============================] - 3s 566us/step - loss: 0.4260 - acc: 0.8335 - val_loss: 0.5080 - val_acc: 0.8077
#
# Epoch 00011: val_acc did not improve from 0.82840
# Epoch 12/40
# 6084/6084 [==============================] - 4s 577us/step - loss: 0.4134 - acc: 0.8401 - val_loss: 0.6093 - val_acc: 0.7929
#
# Epoch 00012: val_acc did not improve from 0.82840
# Epoch 13/40
# 6084/6084 [==============================] - 3s 567us/step - loss: 0.3811 - acc: 0.8568 - val_loss: 0.5799 - val_acc: 0.8033
#
# Epoch 00013: val_acc did not improve from 0.82840
# Epoch 14/40
# 6084/6084 [==============================] - 3s 558us/step - loss: 0.3685 - acc: 0.8582 - val_loss: 0.4560 - val_acc: 0.8180
#
# Epoch 00014: val_acc did not improve from 0.82840
# Epoch 15/40
# 6084/6084 [==============================] - 4s 583us/step - loss: 0.3365 - acc: 0.8761 - val_loss: 0.4641 - val_acc: 0.8240
#
# Epoch 00015: val_acc did not improve from 0.82840
# Epoch 16/40
# 6084/6084 [==============================] - 3s 544us/step - loss: 0.3221 - acc: 0.8812 - val_loss: 0.4881 - val_acc: 0.8284
#
# Epoch 00016: val_acc did not improve from 0.82840
# Epoch 17/40
# 6084/6084 [==============================] - 4s 581us/step - loss: 0.3039 - acc: 0.8849 - val_loss: 0.4973 - val_acc: 0.8388
#
# Epoch 00017: val_acc improved from 0.82840 to 0.83876, saving model to models/conv.model
# Epoch 18/40
# 6084/6084 [==============================] - 3s 542us/step - loss: 0.3100 - acc: 0.8848 - val_loss: 0.5713 - val_acc: 0.8180
#
# Epoch 00018: val_acc did not improve from 0.83876
# Epoch 19/40
# 6084/6084 [==============================] - 3s 549us/step - loss: 0.2789 - acc: 0.8983 - val_loss: 0.4664 - val_acc: 0.8432
#
# Epoch 00019: val_acc improved from 0.83876 to 0.84320, saving model to models/conv.model
# Epoch 20/40
# 6084/6084 [==============================] - 3s 561us/step - loss: 0.2745 - acc: 0.9001 - val_loss: 0.4650 - val_acc: 0.8299
#
# Epoch 00020: val_acc did not improve from 0.84320
# Epoch 21/40
# 6084/6084 [==============================] - 3s 535us/step - loss: 0.2432 - acc: 0.9116 - val_loss: 0.4617 - val_acc: 0.8417
#
# Epoch 00021: val_acc did not improve from 0.84320
# Epoch 22/40
# 6084/6084 [==============================] - 3s 558us/step - loss: 0.2431 - acc: 0.9127 - val_loss: 0.4636 - val_acc: 0.8447
#
# Epoch 00022: val_acc improved from 0.84320 to 0.84467, saving model to models/conv.model
# Epoch 23/40
# 6084/6084 [==============================] - 3s 557us/step - loss: 0.2304 - acc: 0.9152 - val_loss: 0.4947 - val_acc: 0.8388
#
# Epoch 00023: val_acc did not improve from 0.84467
# Epoch 24/40
# 6084/6084 [==============================] - 3s 565us/step - loss: 0.2077 - acc: 0.9221 - val_loss: 0.5289 - val_acc: 0.8417
#
# Epoch 00024: val_acc did not improve from 0.84467
# Epoch 25/40
# 6084/6084 [==============================] - 4s 588us/step - loss: 0.1929 - acc: 0.9308 - val_loss: 0.4743 - val_acc: 0.8580
#
# Epoch 00025: val_acc improved from 0.84467 to 0.85799, saving model to models/conv.model
# Epoch 26/40
# 6084/6084 [==============================] - 3s 545us/step - loss: 0.1930 - acc: 0.9306 - val_loss: 0.5030 - val_acc: 0.8447
#
# Epoch 00026: val_acc did not improve from 0.85799
# Epoch 27/40
# 6084/6084 [==============================] - 3s 575us/step - loss: 0.1780 - acc: 0.9370 - val_loss: 0.5069 - val_acc: 0.8624
#
# Epoch 00027: val_acc improved from 0.85799 to 0.86243, saving model to models/conv.model
# Epoch 28/40
# 6084/6084 [==============================] - 4s 588us/step - loss: 0.1778 - acc: 0.9370 - val_loss: 0.4821 - val_acc: 0.8521
#
# Epoch 00028: val_acc did not improve from 0.86243
# Epoch 29/40
# 6084/6084 [==============================] - 4s 585us/step - loss: 0.1649 - acc: 0.9405 - val_loss: 0.5171 - val_acc: 0.8609
#
# Epoch 00029: val_acc did not improve from 0.86243
# Epoch 30/40
# 6084/6084 [==============================] - 4s 604us/step - loss: 0.1675 - acc: 0.9472 - val_loss: 0.5437 - val_acc: 0.8639
#
# Epoch 00030: val_acc improved from 0.86243 to 0.86391, saving model to models/conv.model
# Epoch 31/40
# 6084/6084 [==============================] - 4s 579us/step - loss: 0.1531 - acc: 0.9463 - val_loss: 0.5620 - val_acc: 0.8624
#
# Epoch 00031: val_acc did not improve from 0.86391
# Epoch 32/40
# 6084/6084 [==============================] - 4s 580us/step - loss: 0.1370 - acc: 0.9499 - val_loss: 0.5768 - val_acc: 0.8550
#
# Epoch 00032: val_acc did not improve from 0.86391
# Epoch 33/40
# 6084/6084 [==============================] - 3s 574us/step - loss: 0.1283 - acc: 0.9569 - val_loss: 0.5493 - val_acc: 0.8698
#
# Epoch 00033: val_acc improved from 0.86391 to 0.86982, saving model to models/conv.model
# Epoch 34/40
# 6084/6084 [==============================] - 3s 571us/step - loss: 0.1327 - acc: 0.9545 - val_loss: 0.5422 - val_acc: 0.8683
#
# Epoch 00034: val_acc did not improve from 0.86982
# Epoch 35/40
# 6084/6084 [==============================] - 3s 566us/step - loss: 0.1338 - acc: 0.9517 - val_loss: 0.5315 - val_acc: 0.8595
#
# Epoch 00035: val_acc did not improve from 0.86982
# Epoch 36/40
# 6084/6084 [==============================] - 3s 566us/step - loss: 0.1420 - acc: 0.9515 - val_loss: 0.5872 - val_acc: 0.8491
#
# Epoch 00036: val_acc did not improve from 0.86982
# Epoch 37/40
# 6084/6084 [==============================] - 4s 590us/step - loss: 0.1432 - acc: 0.9497 - val_loss: 0.5627 - val_acc: 0.8462
#
# Epoch 00037: val_acc did not improve from 0.86982
# Epoch 38/40
# 6084/6084 [==============================] - 4s 595us/step - loss: 0.1215 - acc: 0.9596 - val_loss: 0.6521 - val_acc: 0.8565
#
# Epoch 00038: val_acc did not improve from 0.86982
# Epoch 39/40
# 6084/6084 [==============================] - 4s 585us/step - loss: 0.1124 - acc: 0.9622 - val_loss: 0.6142 - val_acc: 0.8654
#
# Epoch 00039: val_acc did not improve from 0.86982
# Epoch 40/40
# 6084/6084 [==============================] - 4s 588us/step - loss: 0.1212 - acc: 0.9597 - val_loss: 0.5781 - val_acc: 0.8580
# Epoch 00040: val_acc did not improve from 0.86982

# %%
# list all data in history
print(history1.history.keys())
# summarize history for accuracy
plt.plot(history1.history['acc'])
plt.plot(history1.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
#mang nay them 1 lop dense 32 truoc lop softmax cua conv
checkpoint = ModelCheckpoint(config.model_path, monitor='val_acc', verbose=1, mode = 'max', save_best_only=True, save_weights_only=False, period=1)
model = load_model('voice_conv_2.h5')
print('class_weight: ',class_weight)
history1 = model.fit(X, y, epochs=40, batch_size=16, shuffle=True, validation_split=0.1, callbacks = [checkpoint])
model.save('voice_conv_2.h5')
# Out:
# class_weight:  [1.20714286 0.98141696 0.83087512 1.09032258 1.02798054 0.813282
#  1.06423174 1.12367021]
# Train on 6084 samples, validate on 676 samples
# Epoch 1/40
# 6084/6084 [==============================] - 4s 647us/step - loss: 0.1072 - acc: 0.9645 - val_loss: 0.5927 - val_acc: 0.8521
#
# Epoch 00001: val_acc improved from -inf to 0.85207, saving model to models/conv.model
# Epoch 2/40
# 6084/6084 [==============================] - 3s 558us/step - loss: 0.0967 - acc: 0.9650 - val_loss: 0.6248 - val_acc: 0.8506
#
# Epoch 00002: val_acc did not improve from 0.85207
# Epoch 3/40
# 6084/6084 [==============================] - 3s 524us/step - loss: 0.1054 - acc: 0.9663 - val_loss: 0.6137 - val_acc: 0.8595
#
# Epoch 00003: val_acc improved from 0.85207 to 0.85947, saving model to models/conv.model
# Epoch 4/40
# 6084/6084 [==============================] - 3s 541us/step - loss: 0.1210 - acc: 0.9610 - val_loss: 0.5898 - val_acc: 0.8358
#
# Epoch 00004: val_acc did not improve from 0.85947
# Epoch 5/40
# 6084/6084 [==============================] - 3s 532us/step - loss: 0.0973 - acc: 0.9684 - val_loss: 0.5948 - val_acc: 0.8639
#
# Epoch 00005: val_acc improved from 0.85947 to 0.86391, saving model to models/conv.model
# Epoch 6/40
# 6084/6084 [==============================] - 3s 529us/step - loss: 0.0837 - acc: 0.9707 - val_loss: 0.6576 - val_acc: 0.8476
#
# Epoch 00006: val_acc did not improve from 0.86391
# Epoch 7/40
# 6084/6084 [==============================] - 3s 537us/step - loss: 0.0862 - acc: 0.9714 - val_loss: 0.7242 - val_acc: 0.8432
#
# Epoch 00007: val_acc did not improve from 0.86391
# Epoch 8/40
# 6084/6084 [==============================] - 4s 586us/step - loss: 0.1141 - acc: 0.9606 - val_loss: 0.7079 - val_acc: 0.8550
#
# Epoch 00008: val_acc did not improve from 0.86391
# Epoch 9/40
# 6084/6084 [==============================] - 3s 568us/step - loss: 0.0913 - acc: 0.9668 - val_loss: 0.7468 - val_acc: 0.8491
#
# Epoch 00009: val_acc did not improve from 0.86391
# Epoch 10/40
# 6084/6084 [==============================] - 3s 552us/step - loss: 0.0879 - acc: 0.9689 - val_loss: 0.6921 - val_acc: 0.8654
#
# Epoch 00010: val_acc improved from 0.86391 to 0.86538, saving model to models/conv.model
# Epoch 11/40
# 6084/6084 [==============================] - 3s 556us/step - loss: 0.0764 - acc: 0.9722 - val_loss: 0.6992 - val_acc: 0.8565
#
# Epoch 00011: val_acc did not improve from 0.86538
# Epoch 12/40
# 6084/6084 [==============================] - 3s 555us/step - loss: 0.0923 - acc: 0.9716 - val_loss: 0.7039 - val_acc: 0.8713
#
# Epoch 00012: val_acc improved from 0.86538 to 0.87130, saving model to models/conv.model
# Epoch 13/40
# 6084/6084 [==============================] - 3s 555us/step - loss: 0.0838 - acc: 0.9721 - val_loss: 0.7147 - val_acc: 0.8683
#
# Epoch 00013: val_acc did not improve from 0.87130
# Epoch 14/40
# 6084/6084 [==============================] - 3s 551us/step - loss: 0.0702 - acc: 0.9745 - val_loss: 0.7083 - val_acc: 0.8743
#
# Epoch 00014: val_acc improved from 0.87130 to 0.87426, saving model to models/conv.model
# Epoch 15/40
# 6084/6084 [==============================] - 3s 555us/step - loss: 0.0953 - acc: 0.9722 - val_loss: 0.6155 - val_acc: 0.8698
#
# Epoch 00015: val_acc did not improve from 0.87426
# Epoch 16/40
# 6084/6084 [==============================] - 3s 553us/step - loss: 0.0853 - acc: 0.9726 - val_loss: 0.5889 - val_acc: 0.8565
#
# Epoch 00016: val_acc did not improve from 0.87426
# Epoch 17/40
# 6084/6084 [==============================] - 3s 555us/step - loss: 0.0698 - acc: 0.9727 - val_loss: 0.6753 - val_acc: 0.8595
#
# Epoch 00017: val_acc did not improve from 0.87426
# Epoch 18/40
# 6084/6084 [==============================] - 3s 561us/step - loss: 0.0897 - acc: 0.9704 - val_loss: 0.6900 - val_acc: 0.8624
#
# Epoch 00018: val_acc did not improve from 0.87426
# Epoch 19/40
# 6084/6084 [==============================] - 4s 590us/step - loss: 0.0866 - acc: 0.9702 - val_loss: 0.6713 - val_acc: 0.8624
#
# Epoch 00019: val_acc did not improve from 0.87426
# Epoch 20/40
# 6084/6084 [==============================] - 4s 583us/step - loss: 0.0723 - acc: 0.9760 - val_loss: 0.6768 - val_acc: 0.8565
#
# Epoch 00020: val_acc did not improve from 0.87426
# Epoch 21/40
# 6084/6084 [==============================] - 4s 582us/step - loss: 0.0749 - acc: 0.9753 - val_loss: 0.6201 - val_acc: 0.8654
#
# Epoch 00021: val_acc did not improve from 0.87426
# Epoch 22/40
# 6084/6084 [==============================] - 4s 584us/step - loss: 0.0758 - acc: 0.9752 - val_loss: 0.6970 - val_acc: 0.8609
#
# Epoch 00022: val_acc did not improve from 0.87426
# Epoch 23/40
# 6084/6084 [==============================] - 4s 593us/step - loss: 0.0854 - acc: 0.9727 - val_loss: 0.6711 - val_acc: 0.8609
#
# Epoch 00023: val_acc did not improve from 0.87426
# Epoch 24/40
# 6084/6084 [==============================] - 4s 593us/step - loss: 0.0748 - acc: 0.9785 - val_loss: 0.6528 - val_acc: 0.8536
#
# Epoch 00024: val_acc did not improve from 0.87426
# Epoch 25/40
# 6084/6084 [==============================] - 4s 600us/step - loss: 0.0907 - acc: 0.9714 - val_loss: 0.6588 - val_acc: 0.8698
#
# Epoch 00025: val_acc did not improve from 0.87426
# Epoch 26/40
# 6084/6084 [==============================] - 4s 586us/step - loss: 0.0724 - acc: 0.9750 - val_loss: 0.7786 - val_acc: 0.8698
#
# Epoch 00026: val_acc did not improve from 0.87426
# Epoch 27/40
# 6084/6084 [==============================] - 4s 590us/step - loss: 0.0617 - acc: 0.9811 - val_loss: 0.8213 - val_acc: 0.8654
#
# Epoch 00027: val_acc did not improve from 0.87426
# Epoch 28/40
# 6084/6084 [==============================] - 4s 595us/step - loss: 0.0701 - acc: 0.9803 - val_loss: 0.6956 - val_acc: 0.8536
#
# Epoch 00028: val_acc did not improve from 0.87426
# Epoch 29/40
# 6084/6084 [==============================] - 4s 590us/step - loss: 0.0813 - acc: 0.9775 - val_loss: 0.6817 - val_acc: 0.8713
#
# Epoch 00029: val_acc did not improve from 0.87426
# Epoch 30/40
# 6084/6084 [==============================] - 4s 593us/step - loss: 0.0576 - acc: 0.9816 - val_loss: 0.7404 - val_acc: 0.8639
#
# Epoch 00030: val_acc did not improve from 0.87426
# Epoch 31/40
# 6084/6084 [==============================] - 4s 590us/step - loss: 0.0687 - acc: 0.9772 - val_loss: 0.8046 - val_acc: 0.8609
#
# Epoch 00031: val_acc did not improve from 0.87426
# Epoch 32/40
# 6084/6084 [==============================] - 4s 592us/step - loss: 0.0737 - acc: 0.9768 - val_loss: 0.7736 - val_acc: 0.8580
#
# Epoch 00032: val_acc did not improve from 0.87426
# Epoch 33/40
# 6084/6084 [==============================] - 4s 590us/step - loss: 0.0718 - acc: 0.9767 - val_loss: 0.6997 - val_acc: 0.8521
#
# Epoch 00033: val_acc did not improve from 0.87426
# Epoch 34/40
# 6084/6084 [==============================] - 4s 589us/step - loss: 0.0703 - acc: 0.9785 - val_loss: 0.7044 - val_acc: 0.8787
#
# Epoch 00034: val_acc improved from 0.87426 to 0.87870, saving model to models/conv.model
# Epoch 35/40
# 6084/6084 [==============================] - 4s 597us/step - loss: 0.0593 - acc: 0.9814 - val_loss: 0.7906 - val_acc: 0.8536
#
# Epoch 00035: val_acc did not improve from 0.87870
# Epoch 36/40
# 6084/6084 [==============================] - 4s 592us/step - loss: 0.0531 - acc: 0.9818 - val_loss: 0.7984 - val_acc: 0.8580
#
# Epoch 00036: val_acc did not improve from 0.87870
# Epoch 37/40
# 6084/6084 [==============================] - 4s 590us/step - loss: 0.0674 - acc: 0.9790 - val_loss: 0.8792 - val_acc: 0.8669
#
# Epoch 00037: val_acc did not improve from 0.87870
# Epoch 38/40
# 6084/6084 [==============================] - 4s 591us/step - loss: 0.0691 - acc: 0.9762 - val_loss: 0.7596 - val_acc: 0.8639
#
# Epoch 00038: val_acc did not improve from 0.87870
# Epoch 39/40
# 6084/6084 [==============================] - 4s 587us/step - loss: 0.0433 - acc: 0.9864 - val_loss: 0.6845 - val_acc: 0.8713
#
# Epoch 00039: val_acc did not improve from 0.87870
# Epoch 40/40
# 6084/6084 [==============================] - 4s 595us/step - loss: 0.0670 - acc: 0.9803 - val_loss: 0.6969 - val_acc: 0.8462
#
# Epoch 00040: val_acc did not improve from 0.87870

# %%
# list all data in history
print(history1.history.keys())
# summarize history for accuracy
plt.plot(history1.history['acc'])
plt.plot(history1.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %% [markdown]
# # ================================================================

# %%
class Config:
    def __init__(self, mode='conv', nfilt=26, nfeat=13, nfft=512, rate=16000):
        self.mode = mode
        self.nfilt = nfilt
        self.nfeat = nfeat
        self.nfft = nfft
        self.rate = rate
        self.step = int(rate/10)
    
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
def build_rand_feat():
    X = []
    y = []
    _min, _max = float('inf'), -float('inf')
    print('tqdm: ',n_samples)
    for _ in tqdm(range(int(n_samples))):
        rand_class = np.random.choice(class_dist.index, p = prob_dist)
        file = np.random.choice(df[df.label==rand_class].index)
        rate, wav = wavfile.read('clean_voice/'+file)
        label = df.at[file, 'label']
        rand_index = np.random.randint(0, wav.shape[0]-config.step)
        sample = wav[rand_index:rand_index+config.step]
        X_sample = mfcc(sample, rate, numcep=config.nfeat, nfilt=config.nfilt, nfft=config.nfft).T
        _min = min(np.amin(X_sample), _min)
        _max = max(np.amax(X_sample), _max)
        X.append(X_sample if config.mode == 'conv' else X_sample.T)
        y.append(classes.index(label))
    X, y = np.array(X), np.array(y)
    X = (X - _min) / (_max - _min)
    if config.mode == 'conv':
        X = X.reshape(X.shape[0], X.shape[1], X.shape[2], 1)
    elif config.mode == 'time':
        X = X.reshape(X.shape[0], X.shape[1], X.shape[2])
    y = to_categorical(y, num_classes=8)
    return X, y, _min, _max

def build_rand_feat():
    X = []
    y = []
    _min, _max = float('inf'), -float('inf')
    print('tqdm: ',n_samples)
    for _ in tqdm(range(int(n_samples))):
        rand_class = np.random.choice(class_dist.index, p = prob_dist)
        file = np.random.choice(df[df.label==rand_class].index)
        rate, wav = wavfile.read('clean_voice/'+file)
        label = df.at[file, 'label']
        rand_index = np.random.randint(0, wav.shape[0]-config.step)
        sample = wav[rand_index:rand_index+config.step]
        X_sample = mfcc(sample, rate, numcep=config.nfeat, nfilt=config.nfilt, nfft=config.nfft).T
        _min = min(np.amin(X_sample), _min)
        _max = max(np.amax(X_sample), _max)
        X.append(X_sample if config.mode == 'conv' else X_sample.T)
        y.append(classes.index(label))
    X, y = np.array(X), np.array(y)
    X = (X - _min) / (_max - _min)
    if config.mode == 'conv':
        X = X.reshape(X.shape[0], X.shape[1], X.shape[2], 1)
    elif config.mode == 'time':
        X = X.reshape(X.shape[0], X.shape[1], X.shape[2])
    y = to_categorical(y, num_classes=8)
    return X, y, _min, _max

def envelope(y, rate, threshold):
    mask = []
    y = pd.Series(y).apply(np.abs)
    y_mean = y.rolling(window=int(rate/10), min_periods = 1, center = True).mean()
    for mean in y_mean:
        if mean > threshold:
            mask.append(True)
        else:
            mask.append(False)
    return mask

def calc_fft(y, rate):
    n = len(y)
    freq = np.fft.rfftfreq(n, d=1/rate)
    Y = abs(np.fft.rfft(y)/n)
    return(Y, freq)

def plot_signals(signals):
    fig, axes = plt.subplots(nrows=2, ncols=4, sharex=False,
                             sharey=True, figsize=(20,5))
    fig.suptitle('Time Series', size=16)
    i = 0
    for x in range(2):
        for y in range(4):
            axes[x,y].set_title(list(signals.keys())[i])
            axes[x,y].plot(list(signals.values())[i])
            axes[x,y].get_xaxis().set_visible(False)
            axes[x,y].get_yaxis().set_visible(False)
            i += 1

# %%
df = pd.read_csv('voice_label.csv')
df.set_index('fname', inplace=True) # danh so thu tu tung file

for f in df.index:
    rate, signal = wavfile.read('clean_voice/'+f)
    df.at[f, 'length'] = signal.shape[0]/rate

classes = list(np.unique(df.label))
class_dist = df.groupby(['label'])['length'].mean()
print('classes',classes)
print('class_dist',class_dist)

n_samples = 2*int(df['length'].sum())/0.1
prob_dist = class_dist/class_dist.sum()
choices = np.random.choice(class_dist.index, p = prob_dist)
print('n_samples', n_samples)
print('prob_dist', prob_dist)
print('choices', choices)

fig, ax = plt.subplots()
ax.set_title('class Distribution', y=1.08)
ax.pie(class_dist, labels = class_dist.index, autopct='%1.1f%%', shadow=False, startangle=90)
ax.axis('equal')
plt.show()

df.reset_index(inplace=True)
signals = {}
fft = {}
fbank = {}
mfccs = {}

config = Config(mode='conv')

for c in classes:
    wav_file = df[df.label == c].iloc[0,0]
    print(wav_file)
    signal, rate = librosa.load('clean_voice/'+wav_file, sr=44100)
    mask = envelope(signal, rate, 0.0005)
    signal = signal[mask]
    signals[c] = signal
    fft[c] = calc_fft(signal, rate)

    bank = logfbank(signal[:rate], rate, nfilt=26, nfft=1103).T
    fbank[c] = bank
    mel = mfcc(signal[:rate], rate, numcep = 13, nfilt=26, nfft = 1103).T
    mfccs[c] = mel
    
plot_signals(signals)
plt.show()
# Out:
# classes ['ba', 'bay', 'bon', 'hai', 'mot', 'nam', 'sau', 'tam']
# class_dist label
# ba     0.775559
# bay    0.948578
# bon    1.104093
# hai    0.837511
# mot    0.882948
# nam    1.117455
# sau    0.862106
# tam    0.771549
# Name: length, dtype: float64
# n_samples 6760.0
# prob_dist label
# ba     0.106244
# bay    0.129946
# bon    0.151250
# hai    0.114731
# mot    0.120955
# nam    0.153080
# sau    0.118100
# tam    0.105695
# Name: length, dtype: float64
# choices nam
# 3__l106.wav
# 7__l334.wav
# 4__l149.wav
# l65.wav
# chunk38.wav
# 5__l25.wav
# 6__l162.wav
# 8__1l221.wav

# %%
X, y, _min, _max = build_rand_feat()
# Out:
#   0%|          | 0/6760 [00:00<?, ?it/s]
# tqdm:  6760.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-110-c1fb28b264f3> in <module>
# ----> 1 X, y, _min, _max = build_rand_feat()
#
# <ipython-input-107-612a4e5e60c6> in build_rand_feat()
#      50         rand_class = np.random.choice(class_dist.index, p = prob_dist)
#      51         file = np.random.choice(df[df.label==rand_class].index)
# ---> 52         rate, wav = wavfile.read('clean_voice/'+file)
#      53         label = df.at[file, 'label']
#      54         rand_index = np.random.randint(0, wav.shape[0]-config.step)
#
# TypeError: must be str, not numpy.int64
